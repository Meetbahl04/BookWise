# %%
import pandas as pd
import numpy as np
import os

# %%
data = pd.read_csv('BX_Books.csv', sep = ';', on_bad_lines = 'skip', encoding = 'latin-1')

# %%
data
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271374  0440400988                         There's a Bat in Bunk Five
# 271375  0525447644                            From One to One Hundred
# 271376  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271377  0192126040                        Republic (World's Classics)
# 271378  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author  Year-Of-Publication  \
# 0         Mark P. O. Morford                 2002
# 1       Richard Bruce Wright                 2001
# 2               Carlo D'Este                 1991
# 3           Gina Bari Kolata                 1999
# 4            E. J. W. Barber                 1999
# ...                      ...                  ...
# 271374        Paula Danziger                 1988
# 271375            Teri Sloat                 1991
# 271376      Christine Wicker                 2004
# 271377                 Plato                 1996
# 271378   Christopher  Biffle                 2000
#
#                                                Publisher  \
# 0                                Oxford University Press
# 1                                  HarperFlamingo Canada
# 2                                        HarperPerennial
# 3                                   Farrar Straus Giroux
# 4                                 W. W. Norton & Company
# ...                                                  ...
# 271374                   Random House Childrens Pub (Mm)
# 271375                                      Dutton Books
# 271376                                HarperSanFrancisco
# 271377                           Oxford University Press
# 271378  McGraw-Hill Humanities/Social Sciences/Languages
#
#                                               Image-URL-S  \
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 271374  http://images.amazon.com/images/P/0440400988.0...
# 271375  http://images.amazon.com/images/P/0525447644.0...
# 271376  http://images.amazon.com/images/P/006008667X.0...
# 271377  http://images.amazon.com/images/P/0192126040.0...
# 271378  http://images.amazon.com/images/P/0767409752.0...
#
#                                               Image-URL-M  \
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 271374  http://images.amazon.com/images/P/0440400988.0...
# 271375  http://images.amazon.com/images/P/0525447644.0...
# 271376  http://images.amazon.com/images/P/006008667X.0...
# 271377  http://images.amazon.com/images/P/0192126040.0...
# 271378  http://images.amazon.com/images/P/0767409752.0...
#
#                                               Image-URL-L
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 271374  http://images.amazon.com/images/P/0440400988.0...
# 271375  http://images.amazon.com/images/P/0525447644.0...
# 271376  http://images.amazon.com/images/P/006008667X.0...
# 271377  http://images.amazon.com/images/P/0192126040.0...
# 271378  http://images.amazon.com/images/P/0767409752.0...
#
# [271379 rows x 8 columns]

# %%
data.columns
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L'],
#       dtype='object')

# %%
data = data[['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',]]
data.rename(columns = {'ISBN':'isbn', 'Book-Title':'title', 'Book-Author':'book_author', 'Year-Of-Publication':'year', 'Publisher':'publisher'}, inplace = True)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_18912\3350142596.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.rename(columns = {'ISBN':'isbn', 'Book-Title':'title', 'Book-Author':'book_author', 'Year-Of-Publication':'year', 'Publisher':'publisher'}, inplace = True)

# %%
data
# Out:
#               isbn                                              title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271374  0440400988                         There's a Bat in Bunk Five
# 271375  0525447644                            From One to One Hundred
# 271376  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271377  0192126040                        Republic (World's Classics)
# 271378  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  book_author  year  \
# 0         Mark P. O. Morford  2002
# 1       Richard Bruce Wright  2001
# 2               Carlo D'Este  1991
# 3           Gina Bari Kolata  1999
# 4            E. J. W. Barber  1999
# ...                      ...   ...
# 271374        Paula Danziger  1988
# 271375            Teri Sloat  1991
# 271376      Christine Wicker  2004
# 271377                 Plato  1996
# 271378   Christopher  Biffle  2000
#
#                                                publisher
# 0                                Oxford University Press
# 1                                  HarperFlamingo Canada
# 2                                        HarperPerennial
# 3                                   Farrar Straus Giroux
# 4                                 W. W. Norton & Company
# ...                                                  ...
# 271374                   Random House Childrens Pub (Mm)
# 271375                                      Dutton Books
# 271376                                HarperSanFrancisco
# 271377                           Oxford University Press
# 271378  McGraw-Hill Humanities/Social Sciences/Languages
#
# [271379 rows x 5 columns]

# %%
Users = pd.read_csv('BX-Users.csv', sep = ';', on_bad_lines = 'skip', encoding = 'latin-1')

# %%
Users.head(2)
# Out:
#    User-ID                   Location   Age
# 0        1         nyc, new york, usa   NaN
# 1        2  stockton, california, usa  18.0

# %%
Users.rename(columns = {'User-ID' : 'user_id', 'Location' : 'location', 'Age' : 'age'}, inplace = True)

# %%
Users.head(2)
# Out:
#    user_id                   location   age
# 0        1         nyc, new york, usa   NaN
# 1        2  stockton, california, usa  18.0

# %%
ratings = pd.read_csv('BX-Book-Ratings.csv', sep = ';', on_bad_lines = 'skip', encoding = 'latin-1')

# %%
ratings.head(2)
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5

# %%
ratings.rename(columns = {'User-ID':'user_id', 'ISBN':'isbn', 'Book-Rating':'book_rating'}, inplace = True)

# %%
ratings.head(2)
# Out:
#    user_id        isbn  book_rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5

# %%
x = ratings['user_id'].value_counts()>200

# %%
y = x[x].index

# %%
y
# Out:
# Index([ 11676, 198711, 153662,  98391,  35859, 212898, 278418,  76352, 110973,
#        235105,
#        ...
#        260183,  73681,  44296, 155916,   9856, 274808,  28634,  59727, 268622,
#        188951],
#       dtype='int64', name='user_id', length=899)

# %%
ratings = ratings[ratings['user_id'].isin(y)]

# %%
ratings.shape
# Out:
# (526356, 3)

# %%
ratings.head()
# Out:
#       user_id        isbn  book_rating
# 1456   277427  002542730X           10
# 1457   277427  0026217457            0
# 1458   277427  003008685X            8
# 1459   277427  0030615321            0
# 1460   277427  0060002050            0

# %%
z = data['isbn'].value_counts()>50

# %%
ratings_with_books = ratings.merge(data, on = 'isbn')

# %%
ratings_with_books.shape
# Out:
# (487685, 7)

# %%
ratings_with_books.head(3)
# Out:
#    user_id        isbn  book_rating  \
# 0   277427  002542730X           10
# 1   277427  0026217457            0
# 2   277427  003008685X            8
#
#                                                title            book_author  \
# 0  Politically Correct Bedtime Stories: Modern Ta...      James Finn Garner
# 1                 Vegetarian Times Complete Cookbook             Lucy  Moll
# 2                                           Pioneers  James Fenimore Cooper
#
#    year              publisher
# 0  1994  John Wiley & Sons Inc
# 1  1995      John Wiley & Sons
# 2  1974       Thomson Learning

# %%
number_rating = ratings_with_books.groupby('title')['book_rating'].count().reset_index()

# %%
number_rating.rename(columns={'book_rating':'number_of_rating'}, inplace=True)

# %%
number_rating.head()
# Out:
#                                                title  number_of_rating
# 0   A Light in the Storm: The Civil War Diary of ...                 2
# 1                              Always Have Popsicles                 1
# 2               Apple Magic (The Collector's series)                 1
# 3   Beyond IBM: Leadership Marketing and Finance ...                 1
# 4   Clifford Visita El Hospital (Clifford El Gran...                 1

# %%
number_rating.shape
# Out:
# (160280, 2)

# %%
final_rating = ratings_with_books.merge(number_rating, on = 'title')

# %%
final_rating.head(5)
# Out:
#    user_id        isbn  book_rating  \
# 0   277427  002542730X           10
# 1   277427  0026217457            0
# 2   277427  003008685X            8
# 3   277427  0030615321            0
# 4   277427  0060002050            0
#
#                                                title            book_author  \
# 0  Politically Correct Bedtime Stories: Modern Ta...      James Finn Garner
# 1                 Vegetarian Times Complete Cookbook             Lucy  Moll
# 2                                           Pioneers  James Fenimore Cooper
# 3   Ask for May, Settle for June (A Doonesbury book)          G. B. Trudeau
# 4                  On a Wicked Dawn (Cynster Novels)      Stephanie Laurens
#
#    year              publisher  number_of_rating
# 0  1994  John Wiley & Sons Inc                82
# 1  1995      John Wiley & Sons                 7
# 2  1974       Thomson Learning                 1
# 3  1982        Henry Holt & Co                 1
# 4  2002             Avon Books                13

# %%
final_rating=final_rating[final_rating['number_of_rating']>50]

# %%
final_rating.shape
# Out:
# (21412, 10)

# %%
final_rating.head()
# Out:
#    level_0  index  user_id        isbn  book_rating  \
# 0        1     13   277427  0060930535            0
# 1        2     15   277427  0060934417            0
# 2        3     18   277427  0061009059            9
# 3        7     36   277427  014100018X            0
# 4        8     38   277427  0142001740            0
#
#                                                title         book_author  \
# 0                      The Poisonwood Bible: A Novel  Barbara Kingsolver
# 1                                 Bel Canto: A Novel        Ann Patchett
# 2  One for the Money (Stephanie Plum Novels (Pape...     Janet Evanovich
# 3                                           Chocolat       Joanne Harris
# 4                            The Secret Life of Bees       Sue Monk Kidd
#
#    year      publisher  number_of_rating
# 0  1999      Perennial               133
# 1  2002      Perennial               108
# 2  1995    HarperTorch               108
# 3  2000  Penguin Books               103
# 4  2003  Penguin Books               209

# %%
final_rating = final_rating.reset_index()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18912\889608556.py in ?()
# ----> 1 final_rating = final_rating.reset_index()
#
# ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py in ?(self, level, drop, inplace, col_level, col_fill, allow_duplicates, names)
#    6468                     level_values = algorithms.take(
#    6469                         level_values, lab, allow_fill=True, fill_value=lev._na_value
#    6470                     )
#    6471
# -> 6472                 new_obj.insert(
#    6473                     0,
#    6474                     name,
#    6475                     level_values,
#
# ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py in ?(self, loc, column, value, allow_duplicates)
#    5154                 "'self.flags.allows_duplicate_labels' is False."
#    5155             )
#    5156         if not allow_duplicates and column in self.columns:
#    5157             # Should this be a different kind of error??
# -> 5158             raise ValueError(f"cannot insert {column}, already exists")
#    5159         if not is_integer(loc):
#    5160             raise TypeError("loc must be int")
#    5161         # convert non stdlib ints to satisfy typing checks
#
# ValueError: cannot insert level_0, already exists

# %%
final_rating.drop_duplicates(['user_id', 'title'], inplace = True)

# %%
final_rating.shape
# Out:
# (21412, 10)

# %%
final_rating.head(10)
# Out:
#    level_0  index  user_id        isbn  book_rating  \
# 0        1     13   277427  0060930535            0
# 1        2     15   277427  0060934417            0
# 2        3     18   277427  0061009059            9
# 3        7     36   277427  014100018X            0
# 4        8     38   277427  0142001740            0
# 5        9     56   277427  0312966091            0
# 6       11     59   277427  0316096199            0
# 7       13     61   277427  0316284955            0
# 8       14     62   277427  0316569321            0
# 9       16     64   277427  0316666343            0
#
#                                                title         book_author  \
# 0                      The Poisonwood Bible: A Novel  Barbara Kingsolver
# 1                                 Bel Canto: A Novel        Ann Patchett
# 2  One for the Money (Stephanie Plum Novels (Pape...     Janet Evanovich
# 3                                           Chocolat       Joanne Harris
# 4                            The Secret Life of Bees       Sue Monk Kidd
# 5  Three To Get Deadly : A Stephanie Plum Novel (...     Janet Evanovich
# 6                                   Lucky : A Memoir        Alice Sebold
# 7       White Oleander : A Novel (Oprah's Book Club)         Janet Fitch
# 8                           White Oleander : A Novel         Janet Fitch
# 9                          The Lovely Bones: A Novel        Alice Sebold
#
#    year                publisher  number_of_rating
# 0  1999                Perennial               133
# 1  2002                Perennial               108
# 2  1995              HarperTorch               108
# 3  2000            Penguin Books               103
# 4  2003            Penguin Books               209
# 5  1998  St. Martin's Paperbacks               105
# 6  2002           Back Bay Books               115
# 7  2000           Back Bay Books               114
# 8  1999            Little, Brown               116
# 9  2002            Little, Brown               270

# %%
books_pivot = final_rating.pivot_table(columns = 'user_id', index = 'title', values = 'book_rating')

# %%
books_pivot.head()
# Out:
# user_id                                             254     2276    2766    \
# title
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN    10.0     NaN
# A Bend in the Road                                     0.0     NaN     7.0
# A Is for Alibi (Kinsey Millhone Mysteries (Pape...     NaN     NaN     7.0
# A Map of the World                                     NaN     NaN     NaN
#
# user_id                                             2977    3363    3757    \
# title
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     NaN     NaN
# A Bend in the Road                                     NaN     NaN     NaN
# A Is for Alibi (Kinsey Millhone Mysteries (Pape...     NaN     NaN     NaN
# A Map of the World                                     NaN     NaN     NaN
#
# user_id                                             4017    4385    6242    \
# title
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     NaN     NaN
# A Bend in the Road                                     NaN     NaN     NaN
# A Is for Alibi (Kinsey Millhone Mysteries (Pape...     NaN     NaN     NaN
# A Map of the World                                     NaN     NaN     NaN
#
# user_id                                             6251    ...  274004  \
# title                                                       ...
# 1st to Die: A Novel                                    NaN  ...     NaN
# 2nd Chance                                             NaN  ...     NaN
# A Bend in the Road                                     NaN  ...     NaN
# A Is for Alibi (Kinsey Millhone Mysteries (Pape...     NaN  ...     NaN
# A Map of the World                                     NaN  ...     NaN
#
# user_id                                             274061  274301  274308  \
# title
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     NaN     0.0
# A Bend in the Road                                     NaN     NaN     NaN
# A Is for Alibi (Kinsey Millhone Mysteries (Pape...     NaN    10.0     0.0
# A Map of the World                                     NaN     NaN     NaN
#
# user_id                                             274808  275970  277427  \
# title
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     NaN     NaN
# A Bend in the Road                                     NaN     NaN     NaN
# A Is for Alibi (Kinsey Millhone Mysteries (Pape...     NaN     NaN     NaN
# A Map of the World                                     NaN     NaN     NaN
#
# user_id                                             277478  277639  278418
# title
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     0.0     NaN
# A Bend in the Road                                     NaN     NaN     NaN
# A Is for Alibi (Kinsey Millhone Mysteries (Pape...     NaN     NaN     NaN
# A Map of the World                                     NaN     NaN     NaN
#
# [5 rows x 876 columns]

# %%
books_pivot.shape
# Out:
# (156, 876)

# %%
books_pivot.fillna(0, inplace = True)

# %%
books_pivot
# Out:
# user_id                                             254     2276    2766    \
# title
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# A Bend in the Road                                     0.0     0.0     7.0
# A Is for Alibi (Kinsey Millhone Mysteries (Pape...     0.0     0.0     7.0
# A Map of the World                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# White Oleander : A Novel                               0.0     0.0     0.0
# White Oleander : A Novel (Oprah's Book Club)           0.0     0.0     0.0
# Wicked: The Life and Times of the Wicked Witch ...     0.0     0.0     0.0
# Wild Animus                                            0.0     0.0     6.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# user_id                                             2977    3363    3757    \
# title
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# A Is for Alibi (Kinsey Millhone Mysteries (Pape...     0.0     0.0     0.0
# A Map of the World                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# White Oleander : A Novel                               7.0     0.0     0.0
# White Oleander : A Novel (Oprah's Book Club)           0.0     0.0     0.0
# Wicked: The Life and Times of the Wicked Witch ...     0.0     0.0     0.0
# Wild Animus                                            0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# user_id                                             4017    4385    6242    \
# title
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# A Is for Alibi (Kinsey Millhone Mysteries (Pape...     0.0     0.0     0.0
# A Map of the World                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# White Oleander : A Novel                               0.0     0.0     0.0
# White Oleander : A Novel (Oprah's Book Club)           0.0     0.0     0.0
# Wicked: The Life and Times of the Wicked Witch ...     0.0     0.0     7.0
# Wild Animus                                            0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# user_id                                             6251    ...  274004  \
# title                                                       ...
# 1st to Die: A Novel                                    0.0  ...     0.0
# 2nd Chance                                             0.0  ...     0.0
# A Bend in the Road                                     0.0  ...     0.0
# A Is for Alibi (Kinsey Millhone Mysteries (Pape...     0.0  ...     0.0
# A Map of the World                                     0.0  ...     0.0
# ...                                                    ...  ...     ...
# White Oleander : A Novel                               8.0  ...     0.0
# White Oleander : A Novel (Oprah's Book Club)           0.0  ...     0.0
# Wicked: The Life and Times of the Wicked Witch ...     0.0  ...     0.0
# Wild Animus                                            0.0  ...     0.0
# \O\" Is for Outlaw"                                    0.0  ...     0.0
#
# user_id                                             274061  274301  274308  \
# title
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# A Is for Alibi (Kinsey Millhone Mysteries (Pape...     0.0    10.0     0.0
# A Map of the World                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# White Oleander : A Novel                               0.0     0.0     0.0
# White Oleander : A Novel (Oprah's Book Club)           0.0     0.0     0.0
# Wicked: The Life and Times of the Wicked Witch ...     0.0     0.0     0.0
# Wild Animus                                            0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     8.0     0.0
#
# user_id                                             274808  275970  277427  \
# title
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# A Is for Alibi (Kinsey Millhone Mysteries (Pape...     0.0     0.0     0.0
# A Map of the World                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# White Oleander : A Novel                               0.0     0.0     0.0
# White Oleander : A Novel (Oprah's Book Club)           0.0     0.0     0.0
# Wicked: The Life and Times of the Wicked Witch ...     0.0     0.0     0.0
# Wild Animus                                            0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# user_id                                             277478  277639  278418
# title
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# A Is for Alibi (Kinsey Millhone Mysteries (Pape...     0.0     0.0     0.0
# A Map of the World                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# White Oleander : A Novel                               0.0     0.0     0.0
# White Oleander : A Novel (Oprah's Book Club)           0.0     0.0     0.0
# Wicked: The Life and Times of the Wicked Witch ...     0.0     0.0     0.0
# Wild Animus                                            0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# [156 rows x 876 columns]

# %%
from scipy.sparse import csr_matrix
book_sparse = csr_matrix(books_pivot)

# %%
type(books_pivot)
# Out:
# pandas.core.frame.DataFrame

# %%
type(book_sparse)
# Out:
# scipy.sparse._csr.csr_matrix

# %%
from sklearn.neighbors import NearestNeighbors
model = NearestNeighbors(n_neighbors = 6, metric = 'cosine')
model.fit(book_sparse)
distances, suggestions = model.kneighbors(books_pivot.iloc[47, :].to_numpy().reshape(1, -1))

# %%
distances
# Out:
# array([[0.        , 0.83717628, 0.84220896, 0.84471615, 0.85119337,
#         0.85310707]])

# %%
suggestions
# Out:
# array([[ 47, 149,  82,  28, 153,  50]], dtype=int64)

# %%
for i in range(len(suggestions)):
    print(books_pivot.index[suggestions[i]])
# Out:
# Index(['How Stella Got Her Groove Back', 'While I Was Gone',
#        'Snow Falling on Cedars',
#        'Divine Secrets of the Ya-Ya Sisterhood: A Novel',
#        'Wicked: The Life and Times of the Wicked Witch of the West',
#        'Into Thin Air : A Personal Account of the Mt. Everest Disaster'],
#       dtype='object', name='title')

# %%
np.where(books_pivot.index == 'Animal Farm')[0][0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[337], line 1
# ----> 1 np.where(books_pivot.index == 'Animal Farm')[0][0]
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
import numpy as np

def book_recommend(book_name):
    book_id = np.where(books_pivot.index == book_name)[0][0]
    distances, suggestions = model.kneighbors(books_pivot.iloc[book_id, :].to_numpy().reshape(1, -1))
    
    print(f"Suggestions for the book '{book_name}':")
    for i, book_index in enumerate(suggestions[0], start=1):
        print(f"{i}. {books_pivot.index[book_index]}")

# %%
book_recommend('Animal Farm')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[341], line 1
# ----> 1 book_recommend('Animal Farm')
#
# Cell In[339], line 4, in book_recommend(book_name)
#       3 def book_recommend(book_name):
# ----> 4     book_id = np.where(books_pivot.index == book_name)[0][0]
#       5     distances, suggestions = model.kneighbors(books_pivot.iloc[book_id, :].to_numpy().reshape(1, -1))
#       7     print(f"Suggestions for the book '{book_name}':")
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
def precision_recall(recommended_books, actual_books):
    relevant_recommendations = len(set(recommended_books) & set(actual_books))
    precision = relevant_recommendations / len(recommended_books)
    recall = relevant_recommendations / len(actual_books)
    return precision, recall

actual_books = ["1984", "Brave New World", "Fahrenheit 451"]  # Replace with real ground truth data
recommended_books = [books_pivot.index[i] for i in suggestions[0]]

precision, recall = precision_recall(recommended_books, actual_books)
print(f"Precision: {precision}, Recall: {recall}")
# Out:
# Precision: 0.0, Recall: 0.0
